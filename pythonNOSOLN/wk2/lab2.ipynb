# %% [markdown]
# # Lab 2

# %% [markdown]
# ## Problem 1

# %% [markdown]
# Write code that will print out `True` if $c$ is strictly between $a$ and $b$ and `False` otherwise. Check your code with different values for $a$, $b$, and $c$.

# %%
# import the random module to generate some random numbers
import random
a = random.uniform(-1, 2)
b = random.uniform(-1, 3)
c = random.uniform(-1, 3)

print(a, b, c)

# Add your code here

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Modify the code below from lecture to add a while loop that will check if the number entered by the user is able to be parsed into an int.
# If it is break out of the while loop and check if the number if a prime.
# If not, continually ask the user to enter a number. Use the <b>`str.isnumeric`()</b> function.

# %%
# add your while loop to this code

user_str = input("Enter an int")

# convert it to an int
n = int(user_str)

is_prime = True
# loop through the numbers 2 to (n - 1)
for m in range(2, n):
    # if n is evenly divisible by m, we already know n is not a prime
    # so break out of the loop
    if n % m == 0:
        is_prime = False
        break

print("is n prime?", is_prime)

# %% [markdown]
# ## Problem 3

# %% [markdown]
# Fill in the code below so that the following table is printed out.
# Hint: Use a while loop and at each iteration multiply the loop variable by 2.
#
# <pre>n	n^2	log(n)	n*log(n)
# 4 	 16 	 1.39 	 5.56
# 8 	 64 	 2.08 	 16.64
# 16 	 256 	 2.77 	 44.32
# 32 	 1024 	 3.47 	 111.04
# 64 	 4096 	 4.16 	 266.24
# 128 	 16384 	 4.85 	 620.8
# 256 	 65536 	 5.55 	 1420.8
# </pre>
#
# * Use <b> `math.log()`</b> to calculate the natural log of a number.
# *  Use  <b> `round() `</b>  to only print 2 decimal places.For example:
# ```python
# import math
# print(round(math.log(100), 2))
# ```
#
# will print out:
#
# <pre>
# 4.61
# </pre>

# %%
import math

n = 2
print("n\tn^2\tlog(n)\tn*log(n)")

# Add your code here

# %% [markdown]
# ## Problem 4

# %% [markdown]
# Write a program that prints out all prime numbers between 2 and 500.

# %%
# Fill in your code for the above problem here

# %% [markdown]
# ## Problem 5

# %% [markdown]
# Take your code for Problem 4 above and save it in a file called <b>lab2_problem5.py</b>. Now instead of finding all numbers between 2 and 500, print all prime numbers from 2 to the `sys.argv[1]` command-line argument.
#
# Be sure to include  `import sys` in your .py file.
#
# <b> Include documentation (comments) to your code for full points. </b>
#
# Practice running your program below using %run:

# %%
# %run lab2_problem5.py 500
